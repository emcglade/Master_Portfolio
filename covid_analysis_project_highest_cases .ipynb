# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/emmamcglade/archive/country_wise_latest.csv')
df=df.drop(['WHO Region'], axis=1 )
frame =df.describe(include='all')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)

# %%
print(df)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# 5   Antigua and Barbuda         86       3         65      18          4
# 6             Argentina     167416    3059      72575   91782       4890
# 7               Armenia      37390     711      26665   10014         73
# 8             Australia      15303     167       9311    5825        368
# 9               Austria      20558     713      18246    1599         86
# 10           Azerbaijan      30446     423      23242    6781        396
# 11              Bahamas        382      11         91     280         40
# ...

# %%
df_agg=pd.DataFrame(df.groupby('Country/Region')['Deaths'].agg(sum)).sort_values(by ='Deaths', ascending=False)
# Out:
# /var/folders/94/30lwb_692753pjwd8gqyjm980000gn/T/ipykernel_32305/1302041947.py:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_agg=pd.DataFrame(df.groupby('Country/Region')['Deaths'].agg(sum)).sort_values(by ='Deaths', ascending=False)

# %%
df_agg.head(10)
# Out:
#                 Deaths
# Country/Region
# Belgium           9822
# Argentina         3059
# Bangladesh        2965
# Afghanistan       1269
# Algeria           1163
# Austria            713
# Armenia            711
# Belarus            538
# Azerbaijan         423
# Australia          167

# %%
df_agg.plot(kind='bar', stacked=True, figsize=(12, 6), legend='True', grid='true', title = 'Deaths in 2020 from Covid Per Country')
# Out:
# <Axes: title={'center': 'Deaths in 2020 from Covid Per Country'}, xlabel='Country/Region'>
